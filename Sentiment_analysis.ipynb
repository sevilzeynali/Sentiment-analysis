# %%
#loading python librairies
#The data set is available here : https://www.kaggle.com/kazanova/sentiment140
import pandas as pd
from pandas.core.common import flatten
import numpy as np
import seaborn as sns
import unicodedata
from tqdm.notebook import tqdm_notebook

from matplotlib import pyplot as plt

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding,RNN,Dropout,GlobalAveragePooling1D,Dense,GRUCell
from tensorflow.keras import callbacks
from tensorflow.keras import models

import mlflow
import mlflow.keras
import mlflow.tensorflow

# %%
#loading data set
df=pd.read_csv("train.csv",encoding="latin-1",header = None)
df.columns=['sentiment', 'id', 'date', 'query', 'user', 'tweet']
df = df.drop(columns=['id', 'date', 'query', 'user'], axis=1)
df.head()
# Out:
#    sentiment                                              tweet
# 0          0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  is upset that he can't update his Facebook by ...
# 2          0  @Kenichan I dived many times for the ball. Man...
# 3          0    my whole body feels itchy and like its on fire
# 4          0  @nationwideclass no, it's not behaving at all....

# %%
#replacing the label 4 with 1 
df["sentiment"]= df["sentiment"].replace(4,1)
df.head()
# Out:
#    sentiment                                              tweet
# 0          0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  is upset that he can't update his Facebook by ...
# 2          0  @Kenichan I dived many times for the ball. Man...
# 3          0    my whole body feels itchy and like its on fire
# 4          0  @nationwideclass no, it's not behaving at all....

# %%
#counting des number of labels and their frequencies in data set
df["sentiment"].value_counts()
# Out:
# 0    800000
# 1    800000
# Name: sentiment, dtype: int64

# %%
#counting the pourcentage of each label
df["sentiment"].value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: sentiment, dtype: float64

# %%
#shwoing the proportion of labels in data set
plt.style.use('ggplot')
sns.countplot(x="sentiment",data=df)
# Out:
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
#Cleaning the data set
stop_words = stopwords.words('english')

def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    w = re.sub(r"([?.!,¿])", r" ", w)
    w = re.sub(r'[" "]+', " ", w)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)
    #removing the linkes
    w = re.sub(r"https?://[a-zA-Z0-9./]+", " ", w)
    #removing mails
    w = re.sub(r"[a-zA-Z0-9.-]+@[a-zA-Z.]+", " ", w)
    #removing htags
    w = re.sub(r"#[a-zA-Z0-9]+", "_", w)
    w = re.sub(r"@[a-zA-Z0-9]+", " ", w)
    # remove stopword
    words = word_tokenize(w.strip())
    words = [mot for mot in words if mot not in stop_words]
    return words

tqdm_notebook.pandas()
df["tweet"]= df["tweet"].progress_apply(lambda x :preprocess_sentence(x))
df.head()
# Out:
#   0%|          | 0/1600000 [00:00<?, ?it/s]
#    sentiment                                              tweet
# 0          0  [switchfoot, http, twitpic, com, awww, bummer,...
# 1          0  [upset, update, facebook, texting, might, cry,...
# 2          0  [kenichan, dived, many, times, ball, managed, ...
# 3          0            [whole, body, feels, itchy, like, fire]
# 4          0              [nationwideclass, behaving, mad, see]

# %%
#word cloud for the tweets with sentiment=0
wc=WordCloud(background_color="black",max_words=100,stopwords=stop_words,max_font_size=50)
text_0=""

for comment in df["tweet"][df["sentiment"]==0]:
    comment=' '.join(comment)
    text_0+=comment
# Générer et afficher le nuage de mots

plt.figure(figsize= (10,6)) # Initialisation d'une figure
wc.generate(text_0)           # "Calcul" du wordcloud
plt.imshow(wc) # Affichage
plt.show()

# %%
#word cloud for the tweets with sentiment=1
text_1=""
for comment in df["tweet"][df["sentiment"]==1]:
    comment=' '.join(comment)
    text_1+=comment
# Générer et afficher le nuage de mots

plt.figure(figsize= (10,6)) # Initialisation d'une figure
wc.generate(text_1)           # "Calcul" du wordcloud
plt.imshow(wc) # Affichage
plt.show()

# %%
#plot distribution for the lenght of tweets
sns.displot(list(map(len,df["tweet"])))

# %%
#plot distribution for the tweet lenghts with sentiment=0
sns.displot(list(map(len,df["tweet"][df["sentiment"]==0])))

# %%
#plot distribution for the tweet lenghts with sentiment=1
sns.displot(list(map(len,df["tweet"][df["sentiment"]==1])))

# %%
#dividing the data set into test and train
X_train, X_test, y_train, y_test = train_test_split(df["tweet"], df["sentiment"], test_size=0.2, random_state=1234)

# %%
#vectorizing tweets
tokenizer=Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

X_train=tokenizer.texts_to_sequences(X_train)
X_test=tokenizer.texts_to_sequences(X_test)

X_train=pad_sequences(X_train,maxlen=20,padding="post",truncating="post")
X_test=pad_sequences(X_test,maxlen=20,padding="post",truncating="post")

# %%
#definig our RNN model
words_unique=list(set(flatten(df["tweet"].values)))
num_words=len(words_unique)
max_len = 20
print(num_words)

model=Sequential()
model.add(Embedding(input_dim=num_words,output_dim=max_len,input_length=max_len))
model.add(RNN(GRUCell(128),return_sequences=True))
model.add(Dropout(0.3))
model.add(GlobalAveragePooling1D())
model.add(Dense(256,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(2,activation="sigmoid"))
model.summary()
# Out:
# 586526
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 20, 20)            11730520
# _________________________________________________________________
# rnn_7 (RNN)                  (None, 20, 128)           57600
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 20, 128)           0
# _________________________________________________________________
# global_average_pooling1d_7 ( (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 11,821,658
# Trainable params: 11,821,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the model
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
#definig the callbacks
lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'loss',
                                             patience = 2,
                                             factor = 0.2,
                                             verbose = 2,
                                             mode = 'min',
                                             min_lr=0)
early_stopping = callbacks.EarlyStopping(monitor = "loss",
                                             patience = 3,
                                             mode = 'min',
                                             verbose = 2,
                                             restore_best_weights= True)
checkpoint = callbacks.ModelCheckpoint(filepath="checkpoint",
                                          monitor = 'loss',
                                          save_best_only = True,
                                          save_weights_only = False,
                                          mode = 'min',
                                          save_freq = 'epoch')

# %%
#https://jayanthkurup.com/keras-utils-generic_utils-has-no-attribute-populate_dict_with_module_objects/
#trainig the model and using mlflow for tracking the model parameters
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("analyse sentiment")

with mlflow.start_run() as run:
    
    history = model.fit(X_train,y_train,epochs = 10,validation_data=(X_test,y_test),callbacks=[lr_plateau,early_stopping, checkpoint],use_multiprocessing= True)
    
    mlflow.tensorflow.autolog()
    
    probs = model.predict(X_test)
    y_pred = np.argmax(probs, axis=1)
    accuracy=accuracy_score(y_test,y_pred)
    fscore=f1_score(y_test,y_pred)
    
    mlflow.log_metric("f1-score",fscore)
    save_name = "model_sentiment_analysis"
    mlflow.keras.log_model(keras_model=model, artifact_path="model")
    mlflow.keras.save_model(keras_model=model, path="model")
    model.save(save_name)
# Out:
# Epoch 1/5
#     5/40000 [..............................] - ETA: 2:09:40 - loss: 0.4942 - accuracy: 0.7812WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0282s vs `on_train_batch_end` time: 0.1109s). Check your callbacks.
# 40000/40000 [==============================] - 1141s 29ms/step - loss: 0.4330 - accuracy: 0.7990 - val_loss: 0.4516 - val_accuracy: 0.7871
# INFO:tensorflow:Assets written to: C:/Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis\check\assets
# Epoch 2/5
# 40000/40000 [==============================] - 1121s 28ms/step - loss: 0.4249 - accuracy: 0.8034 - val_loss: 0.4568 - val_accuracy: 0.7865
# INFO:tensorflow:Assets written to: C:/Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis\check\assets
# Epoch 3/5
# 40000/40000 [==============================] - 1115s 28ms/step - loss: 0.4180 - accuracy: 0.8075 - val_loss: 0.4551 - val_accuracy: 0.7860
# INFO:tensorflow:Assets written to: C:/Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis\check\assets
# Epoch 4/5
# 40000/40000 [==============================] - 1110s 28ms/step - loss: 0.4129 - accuracy: 0.8106 - val_loss: 0.4642 - val_accuracy: 0.7836
# INFO:tensorflow:Assets written to: C:/Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis\check\assets
# Epoch 5/5
# 40000/40000 [==============================] - 1116s 28ms/step - loss: 0.4088 - accuracy: 0.8127 - val_loss: 0.4597 - val_accuracy: 0.7836
# INFO:tensorflow:Assets written to: C:/Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis\check\assets
# INFO:tensorflow:Assets written to: C:\Users\Sevil\AppData\Local\Temp\tmpj0q_l70h\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\Sevil\AppData\Local\Temp\tmp8qphi5pd\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\Sevil\Desktop\git_sevil\model\data\model\assets
# INFO:tensorflow:Assets written to: C:///Users/Sevil/Desktop/datascientest/data_sets/corpus_sentiment_analysis/model_sentiment_analysis\assets

# %%
#model evaluation
model.evaluate(X_test,y_test.values,batch_size=128)
# Out:
# 2500/2500 [==============================] - 53s 21ms/step - loss: 0.4597 - accuracy: 0.7836
# [0.45974037051200867, 0.7835937738418579]

# %%
#confusion matrix
probs = model.predict(X_test)
y_pred = np.argmax(probs, axis=1)

conf_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])

print(conf_matrix)
print(classification_report(y_test,y_pred))

cm = confusion_matrix(y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1])

disp.plot()
plt.show()
# Out:
# Predicted       0       1
# Actual
# 0          122136   37944
# 1           31306  128614
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78    160080
#            1       0.77      0.80      0.79    159920
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000

# %%
#plot loss and accuracy for test and train

plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('val_loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')
plt.show()
